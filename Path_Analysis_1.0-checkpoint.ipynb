# %%
import warnings
warnings.filterwarnings('ignore')
import pandas as pd
from sklearn import preprocessing
import numpy as np
from sklearn import cross_validation
from sklearn import metrics
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\sklearn\cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
data = pd.read_csv("..//data//analytical_data_cleaned.csv",encoding = "ISO-8859-1")

# %%
col_map = pd.read_csv("..//data//question_theme.csv",encoding = "ISO-8859-1")

data.to_csv("..//data//analytical_data_cleaned_new.csv")
col_map.to_csv("..//data//question_theme_new.csv")

# %%
data=data[data['Country']=='US']

# %%
def yes_no_label(x):
    if (x=="No"):
        return 0
    elif (x=="Yes"):
        return 1
    else:
        return 2

for col in col_map[col_map['Theme']=="Chronic condition"]['Column'].tolist():
    data[col]=data[col].apply(yes_no_label)

data=data.drop(['DOB','Age_bucket','Monthly_household_income','Flu_jab_last_6_months','Flu jab frequency',
                'Chronic_conditions_None'],axis=1)

# %%
labeled_data=data.copy()
for col in list(labeled_data.columns):
    label_inter = pd.DataFrame(labeled_data[col].copy())
    label_inter['Column_name']= [col]*len(label_inter)
    label_inter.columns=['Orignal_val','Column_name']
    label_inter = label_inter[['Column_name','Orignal_val']]
    try:
        LE_Var = preprocessing.LabelEncoder()
        LE_Var.fit(labeled_data[col])
        labeled_data[col]=LE_Var.transform(labeled_data[col])
        label_inter['New_val']=labeled_data[col]
    except:
        labeled_data[col]=labeled_data[col].astype(str)
        LE_Var = preprocessing.LabelEncoder()
        LE_Var.fit(labeled_data[col])
        labeled_data[col]=LE_Var.transform(labeled_data[col]) 
        label_inter['New_val']=labeled_data[col]
    try:
        Column_val_map = pd.concat([Column_val_map,label_inter])
    except:
        Column_val_map =label_inter.copy()

# %%
Column_val_map.to_csv("..//output//Column_Value_Mapping.csv")

final_data=labeled_data.copy()
final_data['Adherence_Score']=np.where(final_data['Adherence_Score']>=2,1,0)

data_x =  final_data.drop(['Adherence_Score'],axis=1)
data_y = final_data['Adherence_Score']

X_train, X_test, y_train, y_test = cross_validation.train_test_split(data_x, data_y, test_size=0.2, random_state=42)

from sklearn import svm
clf = svm.SVC(kernel="linear")


clf.fit(X_train, y_train) 
y_pred = clf.predict(X_test)

print("Overall Accuracy = %s" %metrics.accuracy_score(y_pred,y_test))
print("Classification Matrix")
print(metrics.classification_report(y_pred,y_test))
# Out:
# Overall Accuracy = 0.864705882353
# Classification Matrix
#              precision    recall  f1-score   support
#
#           0       0.80      0.94      0.87        79
#           1       0.94      0.80      0.86        91
#
# avg / total       0.87      0.86      0.86       170

# %%
imp= pd.DataFrame(list(data_x.columns))

imp['coefficient']=clf.coef_[0]

svm_weights_selected = (clf.coef_ ** 2).sum(axis=0)
svm_weights_selected /= svm_weights_selected.max()


imp['importance']=svm_weights_selected

imp.columns=['Column_name','Coefficient','Importance']

imp['Filter']="Overall"
imp['Value']="Overall"

# %%
float(imp[imp['Column_name'].isin(['Confident_I_can_get_a_flu_jab_if_I_want_one'])]['Coefficient'])
# Out:
# 0.13895638744880856

# %%
list(labeled_data.columns)
# Out:
# ['Country',
#  'Age',
#  'Gender',
#  'Employment status',
#  'Occupation_type',
#  'Income_bucket',
#  'Marital_status',
#  'self_health_rating',
#  'Diabetes',
#  'High_or_low_BP',
#  'Chronic_lung_condition',
#  'chronic_kidney_condition',
#  'chronic_heart_condition',
#  'weak_immune_condition',
#  'Cancer',
#  'Chronic_neuro_condtion',
#  'In_uncertain_times_I_usually_expect_the_best',
#  'I_am_confident_I_can_achieve_anything_I_set_my_mind_on',
#  'If_something_can_go_wrong_for_me,_it_will',
#  'Willingness_to_take_risks',
#  'Seek_information_about_health_issues_that_worry_me',
#  'Avoid_thinking_about_health_issues_that_worry_me',
#  'Parents_/_spouse_/_relatives_/_friends_help_me_make_decisions_about_my_health',
#  'Participation_with_doctor',
#  'Favouring_vaccination',
#  'Generally_trust_medications',
#  'Generally_trust_vaccination',
#  'Generally_trust_alternative_medicine',
#  'Generally_trust_vaccine_manufacturers_or_pharmaceutical_companies',
#  'Generally_trust_Health_authorites_of_the_country',
#  'Understand_how_vaccination_helps_my_body_fight_infectious_disease',
#  'How_vaccination_works_is_a_mystery_to_me',
#  'Feel_it_is_important_that_I_get_vaccinated',
#  'The_decision_to_get_vaccinated_or_not_is_a_personal_choice',
#  'Vaccination_forms_part_of_a_healthy_lifestyle',
#  'Feel_it_is_important_that_children_get_vaccinated_against_the_flu',
#  'Bad_experience_with_vaccines_or_injections_as_a_child',
#  'Scary_health-related_experience_as_a_child',
#  'Bad_experience_with_healthcare_professionals_as_a_child',
#  'Had_positive_experiences_with_my_healthcare_as_a_child',
#  'Bad_experience_with_vaccines_or_injections_as_an_adult',
#  'Scary_health-related_experience_as_an_adult',
#  'Bad_experience_with_healthcare_professionals_as_an_adult',
#  'Positive_experiences_with_my_healthcare_as_an_adult',
#  'Knowledge_of_flu',
#  'Flu_frequency',
#  'Remember_to_have_the_flu_jab_on_my_own',
#  'Remember_if_I_am_feeling_vulnerable_to_illness',
#  'Remember_when_I_see_it_on_the_news_(such_as_on_TV,_radio_or_in_newspapers)',
#  'Remember_when_I_see_adverts_in_pharmacies_or_my_doctor\x92s_office',
#  'My_doctor_reminds_me_or_sends_a_reminder',
#  'Employer_reminds_me_or_sends_me_a_reminder',
#  'Relatives_or_close_friends_remind_me',
#  'Likeliness_to_get_flu_jab_coming_season',
#  'Know_enough_about_the_flu_jab_to_make_an_informed_decision_on_vaccination',
#  'Trust_the_information_provided_by_Health_Authorities',
#  'Trust_the_information_provided_by_news_reports_on_TV_&_radio_or_newspapers_about_the_flu_jab',
#  'Trust_information_provided_by_general_websites,_YouTube,_blogs,_Facebook_or_Twitter_about_the_flu_jab',
#  'Trust_the_information_provided_by_my_doctor_about_the_flu_jab',
#  'My_doctor_thinks_I_should_get_a_flu_jab',
#  'My_relatives_or_close_friends_thinks_I_should_get_a_flu_jab',
#  'Dont_know_much_about_flu_jab_but_trust_advice',
#  'Worried_about_passing_flu_to_other_people_if_no_flu_jab',
#  'Flu_could_make_me_severely_ill',
#  'Avoid_thinking_about_what_may_happen_if_I_get_the_flu',
#  'Scared_to_pass_flu_to_a_vulnerable_relative',
#  'If_I_got_the_flu,_I_would_feel_sicker_than_other_people_my_age',
#  'If_I_got_the_flu,_I_worry_that_I_would_miss_out_on_important_activities_or_events',
#  'I_believe_that_if_I_got_the_flu_I_would_have_to_stay_in_bed_for\x85',
#  'Confident_I_can_get_a_flu_jab_if_I_want_one',
#  'Taking_action_to_try_to_protect_myself_against_the_flu',
#  'Scared_of_getting_the_flu',
#  'Easy_for_me_to_get_to_a_place_where_I_can_get_the_flu_jab',
#  'I_can_make_time_to_get_the_flu_jab',
#  'Can_afford_flu_shot',
#  'Informed_about_whether_I_should_or_could_get_the_flu_jab',
#  'Open_to_the_idea_of_receiving_the_flu_jab,_in_principle',
#  'If_I_get_a_flu_jab,_it_will_reduce_the_severity_of_the_flu',
#  'With_no_flu_jab,_I_would_feel_very_vulnerable_to_the_flu',
#  'I_get_the_flu_jab_mainly_to_protect_others_who_are_more_vulnerable_than_me',
#  'Confident_I_can_avoid_getting_the_flu,_even_without_the_flu_jab',
#  'Without_a_flu_jab,_I_am_sure_I_would_get_the_flu_this_winter',
#  'If_I_don\x92t_get_a_flu_jab_this_autumn/winter,_the_chances_of_me_getting_flu_are',
#  'Would_regret_not_getting_the_jab',
#  'Having_the_flu_jab_every_year_may_be_dangerous_for_me',
#  'Felt_strong_flu-like_symptoms_after_getting_a_flu_jab',
#  'I_am_scared_of_getting_a_flu_jab',
#  'The_flu_jab_could_give_me_the_flu',
#  'Contents_of_the_flu_jab_may_be_dangerous_for_me',
#  'Allergic_to_the_flu_jab',
#  'Flu_jab_is_painful',
#  'Was_unable_to_get_to_a_place_where_I_could_get_a_flu_jab',
#  'Too_busy_to_get_a_flu_jab',
#  'Couldn\x92t_afford_a_flu_jab',
#  'Forgot_to_get_a_flu_jab',
#  'I_am_healthy,_therefore_I_didn\x92t_need_a_flu_jab',
#  'My_doctor_didn\x92t_recommend_a_flu_jab_to_me',
#  'I_was_not_eligible_for_a_free_flu_jab',
#  'Adherence_Score',
#  'Worried about the contents in flu jab',
#  'Had the flu this winter so dont need flu jab',
#  'Worried about the side effects of flu jab']

# %%
data_4A=labeled_data[['Confident_I_can_get_a_flu_jab_if_I_want_one','Easy_for_me_to_get_to_a_place_where_I_can_get_the_flu_jab',
                      'I_can_make_time_to_get_the_flu_jab','Can_afford_flu_shot']]

# %%
data_4A=data_4A.fillna(0)

# %%
data_4A['combined_index']=0.0000
for col in list(data_4A.columns):
    print(col)
    data_4A['combined_index']=data_4A['combined_index']+data_4A[col].astype(float)
# Out:
# Confident_I_can_get_a_flu_jab_if_I_want_one
# Easy_for_me_to_get_to_a_place_where_I_can_get_the_flu_jab
# I_can_make_time_to_get_the_flu_jab
# Can_afford_flu_shot
# combined_index

# %%
theme_data = data_4A[['combined_index']]

# %%
theme_data.columns=['Availablity']

# %%
Anticipated_Regret=labeled_data[['Worried_about_passing_flu_to_other_people_if_no_flu_jab','Would_regret_not_getting_the_jab']]

# %%
Anticipated_Regret['combined_index']=0.0000
for col in list(Anticipated_Regret.columns):
    print(col)
    Anticipated_Regret['combined_index']=Anticipated_Regret['combined_index']+Anticipated_Regret[col].astype(float)
# Out:
# Worried_about_passing_flu_to_other_people_if_no_flu_jab
# Would_regret_not_getting_the_jab
# combined_index

# %%
theme_data['Anticipated_Regret'] = Anticipated_Regret[['combined_index']]

# %%
attitude = labeled_data[['In_uncertain_times_I_usually_expect_the_best',
                         'I_am_confident_I_can_achieve_anything_I_set_my_mind_on',
                         'If_something_can_go_wrong_for_me,_it_will','Willingness_to_take_risks']]

# %%
attitude['combined_index']=0.0000
for col in list(attitude.columns):
    print(col)
    attitude['combined_index']=attitude['combined_index']+attitude[col].astype(float)
# Out:
# In_uncertain_times_I_usually_expect_the_best
# I_am_confident_I_can_achieve_anything_I_set_my_mind_on
# If_something_can_go_wrong_for_me,_it_will
# Willingness_to_take_risks
# combined_index

# %%
theme_data['attitude'] = attitude[['combined_index']]

# %%
barriers = labeled_data[['Having_the_flu_jab_every_year_may_be_dangerous_for_me',
                        'Felt_strong_flu-like_symptoms_after_getting_a_flu_jab',
                        'I_am_scared_of_getting_a_flu_jab',
                        'The_flu_jab_could_give_me_the_flu',
                        'Contents_of_the_flu_jab_may_be_dangerous_for_me',
                        'Allergic_to_the_flu_jab',
                        'Flu_jab_is_painful',
                        'Worried about the contents in flu jab',
                        'Had the flu this winter so dont need flu jab',
                        'Worried about the side effects of flu jab']]

# %%
barriers['combined_index']=0.0000
for col in list(barriers.columns):
    print(col)
    barriers['combined_index']=barriers['combined_index']+barriers[col].astype(float)
# Out:
# Having_the_flu_jab_every_year_may_be_dangerous_for_me
# Felt_strong_flu-like_symptoms_after_getting_a_flu_jab
# I_am_scared_of_getting_a_flu_jab
# The_flu_jab_could_give_me_the_flu
# Contents_of_the_flu_jab_may_be_dangerous_for_me
# Allergic_to_the_flu_jab
# Flu_jab_is_painful
# Worried about the contents in flu jab
# Had the flu this winter so dont need flu jab
# Worried about the side effects of flu jab
# combined_index

# %%
theme_data['barriers'] = barriers[['combined_index']]

# %%
cues_to_action = labeled_data[['Remember_to_have_the_flu_jab_on_my_own',
                              'Remember_if_I_am_feeling_vulnerable_to_illness',
                              'Remember_when_I_see_it_on_the_news_(such_as_on_TV,_radio_or_in_newspapers)',
                              'Remember_when_I_see_adverts_in_pharmacies_or_my_doctor\x92s_office',
                              'My_doctor_reminds_me_or_sends_a_reminder',
                              'Employer_reminds_me_or_sends_me_a_reminder',
                              'Informed_about_whether_I_should_or_could_get_the_flu_jab']]

# %%
cues_to_action['combined_index']=0.0000
for col in list(cues_to_action.columns):
    print(col)
    cues_to_action['combined_index']=cues_to_action['combined_index']+cues_to_action[col].astype(float)
# Out:
# Remember_to_have_the_flu_jab_on_my_own
# Remember_if_I_am_feeling_vulnerable_to_illness
# Remember_when_I_see_it_on_the_news_(such_as_on_TV,_radio_or_in_newspapers)
# Remember_when_I_see_adverts_in_pharmacies_or_my_doctors_office
# My_doctor_reminds_me_or_sends_a_reminder
# Employer_reminds_me_or_sends_me_a_reminder
# Informed_about_whether_I_should_or_could_get_the_flu_jab
# combined_index

# %%
theme_data['cues_to_action'] = cues_to_action[['combined_index']]

# %%
doctor_rel = labeled_data[['Participation_with_doctor',
                          'My_doctor_thinks_I_should_get_a_flu_jab']]

# %%
doctor_rel['combined_index']=0.0000
for col in list(doctor_rel.columns):
    print(col)
    doctor_rel['combined_index']=doctor_rel['combined_index']+doctor_rel[col].astype(float)
# Out:
# Participation_with_doctor
# My_doctor_thinks_I_should_get_a_flu_jab
# combined_index

# %%
theme_data['doctor_rel'] = doctor_rel[['combined_index']]

# %%
trust_info_chan = labeled_data[['Trust_the_information_provided_by_Health_Authorities',
                               'Trust_the_information_provided_by_news_reports_on_TV_&_radio_or_newspapers_about_the_flu_jab',
                               'Trust_information_provided_by_general_websites,_YouTube,_blogs,_Facebook_or_Twitter_about_the_flu_jab',
                               'Trust_the_information_provided_by_my_doctor_about_the_flu_jab']]

# %%
trust_info_chan['combined_index']=0.0000
for col in list(trust_info_chan.columns):
    print(col)
    trust_info_chan['combined_index']=trust_info_chan['combined_index']+trust_info_chan[col].astype(float)
# Out:
# Trust_the_information_provided_by_Health_Authorities
# Trust_the_information_provided_by_news_reports_on_TV_&_radio_or_newspapers_about_the_flu_jab
# Trust_information_provided_by_general_websites,_YouTube,_blogs,_Facebook_or_Twitter_about_the_flu_jab
# Trust_the_information_provided_by_my_doctor_about_the_flu_jab
# combined_index

# %%
theme_data['trust_info_chan'] = trust_info_chan[['combined_index']]

# %%
knowledge = labeled_data[['Seek_information_about_health_issues_that_worry_me',
                         'Knowledge_of_flu']]

# %%
knowledge['combined_index']=0.0000
for col in list(knowledge.columns):
    print(col)
    knowledge['combined_index']=knowledge['combined_index']+knowledge[col].astype(float)
# Out:
# Seek_information_about_health_issues_that_worry_me
# Knowledge_of_flu
# combined_index

# %%
theme_data['knowledge'] = knowledge[['combined_index']]

# %%
risk_perc = labeled_data[['Flu_could_make_me_severely_ill',
                          'If_I_got_the_flu,_I_would_feel_sicker_than_other_people_my_age',
                          'If_I_got_the_flu,_I_worry_that_I_would_miss_out_on_important_activities_or_events',
                          'I_believe_that_if_I_got_the_flu_I_would_have_to_stay_in_bed_for\x85',
                          'With_no_flu_jab,_I_would_feel_very_vulnerable_to_the_flu',
                          'Confident_I_can_avoid_getting_the_flu,_even_without_the_flu_jab']]

# %%
risk_perc['combined_index']=0.0000
for col in list(risk_perc.columns):
    print(col)
    risk_perc['combined_index']=risk_perc['combined_index']+risk_perc[col].astype(float)
# Out:
# Flu_could_make_me_severely_ill
# If_I_got_the_flu,_I_would_feel_sicker_than_other_people_my_age
# If_I_got_the_flu,_I_worry_that_I_would_miss_out_on_important_activities_or_events
# I_believe_that_if_I_got_the_flu_I_would_have_to_stay_in_bed_for
# With_no_flu_jab,_I_would_feel_very_vulnerable_to_the_flu
# Confident_I_can_avoid_getting_the_flu,_even_without_the_flu_jab
# combined_index

# %%
theme_data['risk_perc'] = risk_perc[['combined_index']]

# %%
vacc_trust = labeled_data[['Favouring_vaccination',
                          'Feel_it_is_important_that_I_get_vaccinated',
                          'Open_to_the_idea_of_receiving_the_flu_jab,_in_principle']]

# %%
vacc_trust['combined_index']=0.0000
for col in list(vacc_trust.columns):
    print(col)
    vacc_trust['combined_index']=vacc_trust['combined_index']+vacc_trust[col].astype(float)
# Out:
# Favouring_vaccination
# Feel_it_is_important_that_I_get_vaccinated
# Open_to_the_idea_of_receiving_the_flu_jab,_in_principle
# combined_index

# %%
theme_data['vacc_trust'] = vacc_trust[['combined_index']]

# %%
past_exper = labeled_data[['Bad_experience_with_vaccines_or_injections_as_a_child',
                          'Bad_experience_with_vaccines_or_injections_as_an_adult']]

# %%
past_exper['combined_index']=0.0000
for col in list(past_exper.columns):
    print(col)
    past_exper['combined_index']=past_exper['combined_index']+past_exper[col].astype(float)
# Out:
# Bad_experience_with_vaccines_or_injections_as_a_child
# Bad_experience_with_vaccines_or_injections_as_an_adult
# combined_index

# %%
theme_data['past_exper'] = past_exper[['combined_index']]

# %%
len(theme_data.index)
# Out:
# 846

# %%
for col in list(theme_data.columns):
    theme_data[col]=np.where(theme_data[col]<=theme_data[col].describe()['50%'],0,1)

# %%
theme_data['Adherence'] = np.where(data['Adherence_Score']<=40,0,1)

# %%
theme_data_orignal= theme_data.copy()

# %%
for col_name in list(theme_data_orignal.columns)[0:len(theme_data_orignal.columns)-1]:
    for col_val in [0,1]:
        for adh in [0,1]:
            theme_data = theme_data_orignal.copy()
            if adh == 1:
                Adherent_str = "Adherent"
                Adherent_flag = 1
            else:
                Adherent_str = "Non Adherent"
                Adherent_flag = 0
            theme_data=theme_data[theme_data[col_name]==col_val]
            theme_data = theme_data.drop([col_name],axis=1)

            data_x =  theme_data.drop(['Adherence'],axis=1)
            data_y = theme_data['Adherence']
            from sklearn import cross_validation
            from sklearn import metrics
            X_train, X_test, y_train, y_test = cross_validation.train_test_split(data_x, data_y, test_size=0.4, random_state=42)

            from sklearn import tree
            clf = tree.DecisionTreeClassifier(max_depth=6)

            #from sklearn.multiclass import OneVsRestClassifier
            #from sklearn.svm import SVC
            #clf = OneVsRestClassifier(SVC(kernel="linear"))
            #from sklearn.ensemble import RandomForestClassifier
            #clf = OneVsRestClassifier(RandomForestClassifier(n_estimators=10))
            #from sklearn.naive_bayes import MultinomialNB
            #clf = OneVsRestClassifier(MultinomialNB(alpha=0.01))
            #from sklearn import svm
            #clf = svm.SVC(kernel="linear")


            #from sklearn.ensemble import RandomForestClassifier
            #clf = RandomForestClassifier(n_estimators=10)
            clf.fit(X_train, y_train) 
            y_pred = clf.predict(X_test)

            print("Overall Accuracy = %s" %metrics.accuracy_score(y_pred,y_test))
            print("Classification Matrix")
            print(metrics.classification_report(y_pred,y_test))



            n_nodes = clf.tree_.node_count
            children_left = clf.tree_.children_left
            children_right = clf.tree_.children_right
            feature = clf.tree_.feature
            threshold = clf.tree_.threshold

            node_depth = np.zeros(shape=n_nodes, dtype=np.int64)
            is_leaves = np.zeros(shape=n_nodes, dtype=bool)
            stack = [(0, -1)]  # seed is the root node id and its parent depth
            while len(stack) > 0:
                node_id, parent_depth = stack.pop()
                node_depth[node_id] = parent_depth + 1

                # If we have a test node
                if (children_left[node_id] != children_right[node_id]):
                    stack.append((children_left[node_id], parent_depth + 1))
                    stack.append((children_right[node_id], parent_depth + 1))
                else:
                    is_leaves[node_id] = True

            node_indicator = clf.decision_path(data_x)
            leave_id = clf.apply(data_x)

            data_node = pd.DataFrame(is_leaves)

            data_node.columns =['Is_Leaf_Node']

            data_node['Sample']=clf.tree_.n_node_samples

            data_node=data_node[data_node['Is_Leaf_Node']==True]

            data_node['Node'] = data_node.index

            data_node=data_node.sort_values(by=['Sample'],ascending=False)

            data_node.index = range(0,len(data_node.index))

            def adh_nadh(x):
                inter=clf.tree_.value[x]
                if inter[0][0]>inter[0][1]:
                    return "Non Adherent"
                else:
                    return "Adherent"

            data_node['Sample_Type']=data_node['Node'].apply(adh_nadh)

            data_node.columns=['Is_Leaf_Node', 'Sample', 'Leaf_Node', 'Sample_Type']

            col_list = list(data_x.columns)

            for leaf_node in data_node['Leaf_Node'].tolist():
                node_trav = leaf_node
                node_id_list=[]
                node_feature_name=[]
                threshold_val_list=[]
                threshold_sign_list=[]
                respondent_count_list = []

                while (node_trav!=0):
                    try:
                        itemindex = np.where(children_left==node_trav)
                        index =itemindex[0][0]
                        node_id_list.append(itemindex[0][0])
                        node_feature_name.append(col_list[feature[itemindex[0][0]]])
                        threshold_val_list.append(threshold[itemindex[0][0]])
                        threshold_sign_list.append("<=")
                        respondent_count_list.append(clf.tree_.value[index][0][0])
                    except:
                        itemindex = np.where(children_right==node_trav)
                        index =itemindex[0][0]
                        node_id_list.append(itemindex[0][0])
                        node_feature_name.append(col_list[feature[itemindex[0][0]]])
                        threshold_val_list.append(threshold[itemindex[0][0]])
                        threshold_sign_list.append(">")  
                        respondent_count_list.append(clf.tree_.value[index][0][1])
                    node_trav = itemindex[0][0]

                path_data=pd.DataFrame([node_id_list,node_feature_name,threshold_val_list,threshold_sign_list,respondent_count_list]).T

                path_data['order'] = list(reversed(range(0,len(path_data.index))))

                path_data['Leaf_Node'] = leaf_node

                path_data.columns=['Node_id','Node_feature_name','threshold_val','threshold_sign','respondent_count','order','Leaf_Node']

                try:
                    master_path_data = pd.concat([master_path_data,path_data])
                except:
                    master_path_data = path_data.copy()



            data_node= data_node[data_node['Sample_Type']==Adherent_str]

            data_node.index = range(0,len(data_node.index))

            master_path_data=master_path_data[master_path_data['Leaf_Node']==data_node['Leaf_Node'][0]].sort_values(by='order')

            master_path_data.index=range(0,len(master_path_data.index))

            theme_data = theme_data[theme_data['Adherence']==Adherent_flag]
            respondent_count_li =[]
            i=0
            for col in master_path_data['Node_feature_name'].tolist():
                str1='theme_data = theme_data[theme_data['+"'"+col+"'"+']'+str(master_path_data[master_path_data['Node_feature_name']==col]['threshold_sign'][i])+str(master_path_data[master_path_data['Node_feature_name']==col]['threshold_val'][i])+"]"   
                exec(str1)
                respondent_count_li.append(len(theme_data.index))
                i=i+1

            master_path_data['respondent_count']=respondent_count_li

            master_path_data['Filter']=col_name
            master_path_data['Value']=col_val
            master_path_data['Adh']=Adherent_str
            
            try:
                master_analysis_data = pd.concat([master_analysis_data,master_path_data])
            except:
                master_analysis_data=master_path_data
# Out:
# Overall Accuracy = 0.707446808511
# Classification Matrix
#              precision    recall  f1-score   support
#
#           0       0.81      0.78      0.80       138
#           1       0.45      0.50      0.48        50
#
# avg / total       0.72      0.71      0.71       188
#
# Overall Accuracy = 0.707446808511
# Classification Matrix
#              precision    recall  f1-score   support
#
#           0       0.81      0.78      0.80       138
#           1       0.45      0.50      0.48        50
#
# avg / total       0.72      0.71      0.71       188
#
# Overall Accuracy = 0.736842105263
# Classification Matrix
#              precision    recall  f1-score   support
#
#           0       0.65      0.61      0.63        56
#           1       0.78      0.81      0.80        96
#
# avg / total       0.73      0.74      0.73       152
#
# Overall Accuracy = 0.736842105263
# Classification Matrix
#              precision    recall  f1-score   support
#
#           0       0.65      0.61      0.63        56
#           1       0.78      0.81      0.80        96
#
# avg / total       0.73      0.74      0.73       152
#
# Overall Accuracy = 0.724719101124
# Classification Matrix
#              precision    recall  f1-score   support
#
#           0       0.87      0.75      0.80       135
#           1       0.45      0.65      0.53        43
#
# avg / total       0.77      0.72      0.74       178
#
# Overall Accuracy = 0.741573033708
# Classification Matrix
#              precision    recall  f1-score   support
#
#           0       0.87      0.77      0.81       132
#           1       0.50      0.67      0.57        46
#
# avg / total       0.77      0.74      0.75       178
#
# Overall Accuracy = 0.776397515528
# Classification Matrix
#              precision    recall  f1-score   support
#
#           0       0.62      0.65      0.63        48
#           1       0.85      0.83      0.84       113
#
# avg / total       0.78      0.78      0.78       161
#
# Overall Accuracy = 0.776397515528
# Classification Matrix
#              precision    recall  f1-score   support
#
#           0       0.60      0.65      0.63        46
#           1       0.86      0.83      0.84       115
#
# avg / total       0.78      0.78      0.78       161
#
# Overall Accuracy = 0.768421052632
# Classification Matrix
#              precision    recall  f1-score   support
#
#           0       0.87      0.75      0.81       122
#           1       0.64      0.79      0.71        68
#
# avg / total       0.79      0.77      0.77       190
#
# Overall Accuracy = 0.768421052632
# Classification Matrix
#              precision    recall  f1-score   support
#
#           0       0.87      0.75      0.81       122
#           1       0.64      0.79      0.71        68
#
# avg / total       0.79      0.77      0.77       190
#
# Overall Accuracy = 0.778523489933
# Classification Matrix
#              precision    recall  f1-score   support
#
#           0       0.79      0.80      0.79        79
#           1       0.77      0.76      0.76        70
#
# avg / total       0.78      0.78      0.78       149
#
# Overall Accuracy = 0.791946308725
# Classification Matrix
#              precision    recall  f1-score   support
#
#           0       0.80      0.81      0.81        79
#           1       0.78      0.77      0.78        70
#
# avg / total       0.79      0.79      0.79       149
#
# Overall Accuracy = 0.847058823529
# Classification Matrix
#              precision    recall  f1-score   support
#
#           0       0.77      0.71      0.74        52
#           1       0.88      0.91      0.89       118
#
# avg / total       0.84      0.85      0.85       170
#
# Overall Accuracy = 0.852941176471
# Classification Matrix
#              precision    recall  f1-score   support
#
#           0       0.77      0.73      0.75        51
#           1       0.89      0.91      0.90       119
#
# avg / total       0.85      0.85      0.85       170
#
# Overall Accuracy = 0.751479289941
# Classification Matrix
#              precision    recall  f1-score   support
#
#           0       0.90      0.79      0.84       140
#           1       0.36      0.59      0.45        29
#
# avg / total       0.81      0.75      0.77       169
#
# Overall Accuracy = 0.745562130178
# Classification Matrix
#              precision    recall  f1-score   support
#
#           0       0.89      0.78      0.84       139
#           1       0.36      0.57      0.44        30
#
# avg / total       0.80      0.75      0.77       169
#
# Overall Accuracy = 0.789772727273
# Classification Matrix
#              precision    recall  f1-score   support
#
#           0       0.92      0.83      0.87       153
#           1       0.32      0.52      0.39        23
#
# avg / total       0.84      0.79      0.81       176
#
# Overall Accuracy = 0.789772727273
# Classification Matrix
#              precision    recall  f1-score   support
#
#           0       0.91      0.83      0.87       151
#           1       0.34      0.52      0.41        25
#
# avg / total       0.83      0.79      0.81       176
#
# Overall Accuracy = 0.748466257669
# Classification Matrix
#              precision    recall  f1-score   support
#
#           0       0.38      0.47      0.42        32
#           1       0.86      0.82      0.84       131
#
# avg / total       0.77      0.75      0.76       163
#
# Overall Accuracy = 0.760736196319
# Classification Matrix
#              precision    recall  f1-score   support
#
#           0       0.38      0.50      0.43        30
#           1       0.88      0.82      0.85       133
#
# avg / total       0.79      0.76      0.77       163
#
# Overall Accuracy = 0.772222222222
# Classification Matrix
#              precision    recall  f1-score   support
#
#           0       0.91      0.78      0.84       139
#           1       0.50      0.73      0.59        41
#
# avg / total       0.82      0.77      0.79       180
#
# Overall Accuracy = 0.761111111111
# Classification Matrix
#              precision    recall  f1-score   support
#
#           0       0.89      0.78      0.83       137
#           1       0.50      0.70      0.58        43
#
# avg / total       0.80      0.76      0.77       180
#
# Overall Accuracy = 0.8
# Classification Matrix
#              precision    recall  f1-score   support
#
#           0       0.71      0.74      0.72        57
#           1       0.85      0.83      0.84       103
#
# avg / total       0.80      0.80      0.80       160
#
# Overall Accuracy = 0.8
# Classification Matrix
#              precision    recall  f1-score   support
#
#           0       0.71      0.74      0.72        57
#           1       0.85      0.83      0.84       103
#
# avg / total       0.80      0.80      0.80       160
#
# Overall Accuracy = 0.840909090909
# Classification Matrix
#              precision    recall  f1-score   support
#
#           0       0.93      0.86      0.89       132
#           1       0.65      0.80      0.71        44
#
# avg / total       0.86      0.84      0.85       176
#
# Overall Accuracy = 0.835227272727
# Classification Matrix
#              precision    recall  f1-score   support
#
#           0       0.93      0.85      0.89       133
#           1       0.63      0.79      0.70        43
#
# avg / total       0.85      0.84      0.84       176
#
# Overall Accuracy = 0.754601226994
# Classification Matrix
#              precision    recall  f1-score   support
#
#           0       0.80      0.60      0.68        72
#           1       0.73      0.88      0.80        91
#
# avg / total       0.76      0.75      0.75       163
#
# Overall Accuracy = 0.742331288344
# Classification Matrix
#              precision    recall  f1-score   support
#
#           0       0.76      0.59      0.66        70
#           1       0.73      0.86      0.79        93
#
# avg / total       0.74      0.74      0.74       163
#
# Overall Accuracy = 0.761467889908
# Classification Matrix
#              precision    recall  f1-score   support
#
#           0       0.87      0.77      0.82       153
#           1       0.58      0.74      0.65        65
#
# avg / total       0.79      0.76      0.77       218
#
# Overall Accuracy = 0.766055045872
# Classification Matrix
#              precision    recall  f1-score   support
#
#           0       0.87      0.78      0.82       152
#           1       0.59      0.74      0.66        66
#
# avg / total       0.79      0.77      0.77       218
#
# Overall Accuracy = 0.752066115702
# Classification Matrix
#              precision    recall  f1-score   support
#
#           0       0.65      0.74      0.69        46
#           1       0.83      0.76      0.79        75
#
# avg / total       0.76      0.75      0.75       121
#
# Overall Accuracy = 0.768595041322
# Classification Matrix
#              precision    recall  f1-score   support
#
#           0       0.69      0.75      0.72        48
#           1       0.83      0.78      0.80        73
#
# avg / total       0.77      0.77      0.77       121
#
# Overall Accuracy = 0.835294117647
# Classification Matrix
#              precision    recall  f1-score   support
#
#           0       0.96      0.83      0.89       138
#           1       0.54      0.84      0.66        32
#
# avg / total       0.88      0.84      0.85       170
#
# Overall Accuracy = 0.835294117647
# Classification Matrix
#              precision    recall  f1-score   support
#
#           0       0.96      0.83      0.89       138
#           1       0.54      0.84      0.66        32
#
# avg / total       0.88      0.84      0.85       170
#
# Overall Accuracy = 0.781065088757
# Classification Matrix
#              precision    recall  f1-score   support
#
#           0       0.76      0.75      0.75        76
#           1       0.80      0.81      0.80        93
#
# avg / total       0.78      0.78      0.78       169
#
# Overall Accuracy = 0.769230769231
# Classification Matrix
#              precision    recall  f1-score   support
#
#           0       0.76      0.73      0.75        78
#           1       0.78      0.80      0.79        91
#
# avg / total       0.77      0.77      0.77       169
#
# Overall Accuracy = 0.835294117647
# Classification Matrix
#              precision    recall  f1-score   support
#
#           0       0.90      0.90      0.90       145
#           1       0.44      0.44      0.44        25
#
# avg / total       0.84      0.84      0.84       170
#
# Overall Accuracy = 0.847058823529
# Classification Matrix
#              precision    recall  f1-score   support
#
#           0       0.92      0.90      0.91       147
#           1       0.44      0.48      0.46        23
#
# avg / total       0.85      0.85      0.85       170
#
# Overall Accuracy = 0.711764705882
# Classification Matrix
#              precision    recall  f1-score   support
#
#           0       0.39      0.40      0.40        40
#           1       0.81      0.81      0.81       130
#
# avg / total       0.71      0.71      0.71       170
#
# Overall Accuracy = 0.717647058824
# Classification Matrix
#              precision    recall  f1-score   support
#
#           0       0.44      0.42      0.43        43
#           1       0.81      0.82      0.81       127
#
# avg / total       0.71      0.72      0.72       170
#
# Overall Accuracy = 0.768965517241
# Classification Matrix
#              precision    recall  f1-score   support
#
#           0       0.84      0.73      0.78       166
#           1       0.70      0.81      0.75       124
#
# avg / total       0.78      0.77      0.77       290
#
# Overall Accuracy = 0.758620689655
# Classification Matrix
#              precision    recall  f1-score   support
#
#           0       0.83      0.72      0.78       167
#           1       0.68      0.80      0.74       123
#
# avg / total       0.77      0.76      0.76       290
#
# Overall Accuracy = 0.673469387755
# Classification Matrix
#              precision    recall  f1-score   support
#
#           0       0.78      0.74      0.76        34
#           1       0.47      0.53      0.50        15
#
# avg / total       0.69      0.67      0.68        49
#
# Overall Accuracy = 0.65306122449
# Classification Matrix
#              precision    recall  f1-score   support
#
#           0       0.72      0.74      0.73        31
#           1       0.53      0.50      0.51        18
#
# avg / total       0.65      0.65      0.65        49

# %%
master_analysis_data=master_analysis_data[['Filter','Value','Adh','order','Node_feature_name','respondent_count','threshold_sign']]

# %%
index_col_map=pd.DataFrame(list(master_analysis_data['Node_feature_name'].unique()))

# %%
index_col_map['neg_map']= ['No Cues for Action' , ' No Trust on Vaccination','Bad Doctor Relationship','Less Knowledge','Bad Attitude','Low Anticipated Regret','Low risk perception','Good past Experience','Low trust on Info Channel','Less Barriers','Low Availablity']

# %%
index_col_map['pos_map']= ['Given Cues for Action' , ' Have Trust on Vaccination','Good  Doctor Relationship','Good Knowledge','Good Attitude','High Anticipated Regret','High risk perception','Bad past Experience','High trust on Info Channel','More Barriers','High Availablity']

# %%
index_col_map.columns=['Node_feature_name', 'neg_map', 'pos_map']

# %%
master_analysis_data=pd.merge(master_analysis_data,index_col_map,on='Node_feature_name',how='left')

# %%
master_analysis_data['Col_Name']= np.where (master_analysis_data['threshold_sign']=="<=",master_analysis_data['neg_map'],master_analysis_data['pos_map'])

# %%
master_analysis_data['Adh']=np.where(master_analysis_data['Adh']=="Adherent","Adhere","Donot Adhere")

# %%
master_analysis_data
# Out:
#                  Filter  Value           Adh  order   Node_feature_name  \
# 0           Availablity      0  Donot Adhere      0      cues_to_action
# 1           Availablity      0  Donot Adhere      1          vacc_trust
# 2           Availablity      0  Donot Adhere      2          doctor_rel
# 3           Availablity      0  Donot Adhere      3           knowledge
# 4           Availablity      0  Donot Adhere      4            attitude
# 5           Availablity      0  Donot Adhere      5  Anticipated_Regret
# 6           Availablity      0        Adhere      0      cues_to_action
# 7           Availablity      0        Adhere      1          vacc_trust
# 8           Availablity      0        Adhere      2           risk_perc
# 9           Availablity      0        Adhere      3          past_exper
# 10          Availablity      1  Donot Adhere      0          vacc_trust
# 11          Availablity      1  Donot Adhere      1  Anticipated_Regret
# 12          Availablity      1  Donot Adhere      2      cues_to_action
# 13          Availablity      1  Donot Adhere      3     trust_info_chan
# 14          Availablity      1        Adhere      0          vacc_trust
# 15          Availablity      1        Adhere      1            barriers
# 16          Availablity      1        Adhere      2      cues_to_action
# 17          Availablity      1        Adhere      3     trust_info_chan
# 18   Anticipated_Regret      0  Donot Adhere      0      cues_to_action
# 19   Anticipated_Regret      0  Donot Adhere      1          vacc_trust
# 20   Anticipated_Regret      0  Donot Adhere      2            attitude
# 21   Anticipated_Regret      0        Adhere      0      cues_to_action
# 22   Anticipated_Regret      0        Adhere      1          vacc_trust
# 23   Anticipated_Regret      0        Adhere      2           risk_perc
# 24   Anticipated_Regret      0        Adhere      3          doctor_rel
# 25   Anticipated_Regret      1  Donot Adhere      0      cues_to_action
# 26   Anticipated_Regret      1  Donot Adhere      1          vacc_trust
# 27   Anticipated_Regret      1  Donot Adhere      2          past_exper
# 28   Anticipated_Regret      1  Donot Adhere      3          doctor_rel
# 29   Anticipated_Regret      1  Donot Adhere      4            barriers
# ..                  ...    ...           ...    ...                 ...
# 188          vacc_trust      1  Donot Adhere      1            barriers
# 189          vacc_trust      1  Donot Adhere      2          doctor_rel
# 190          vacc_trust      1  Donot Adhere      3  Anticipated_Regret
# 191          vacc_trust      1  Donot Adhere      4         Availablity
# 192          vacc_trust      1  Donot Adhere      5           risk_perc
# 193          vacc_trust      1        Adhere      0      cues_to_action
# 194          vacc_trust      1        Adhere      1  Anticipated_Regret
# 195          vacc_trust      1        Adhere      2            attitude
# 196          vacc_trust      1        Adhere      3         Availablity
# 197          past_exper      0  Donot Adhere      0      cues_to_action
# 198          past_exper      0  Donot Adhere      1          vacc_trust
# 199          past_exper      0  Donot Adhere      2  Anticipated_Regret
# 200          past_exper      0  Donot Adhere      3         Availablity
# 201          past_exper      0  Donot Adhere      4           knowledge
# 202          past_exper      0  Donot Adhere      5           risk_perc
# 203          past_exper      0        Adhere      0      cues_to_action
# 204          past_exper      0        Adhere      1          vacc_trust
# 205          past_exper      0        Adhere      2         Availablity
# 206          past_exper      0        Adhere      3  Anticipated_Regret
# 207          past_exper      0        Adhere      4            barriers
# 208          past_exper      0        Adhere      5            attitude
# 209          past_exper      1  Donot Adhere      0            barriers
# 210          past_exper      1  Donot Adhere      1           risk_perc
# 211          past_exper      1  Donot Adhere      2  Anticipated_Regret
# 212          past_exper      1  Donot Adhere      3         Availablity
# 213          past_exper      1  Donot Adhere      4           knowledge
# 214          past_exper      1  Donot Adhere      5      cues_to_action
# 215          past_exper      1        Adhere      0            barriers
# 216          past_exper      1        Adhere      1          vacc_trust
# 217          past_exper      1        Adhere      2         Availablity
#
#      respondent_count threshold_sign                    neg_map  \
# 0                 279             <=         No Cues for Action
# 1                 222             <=    No Trust on Vaccination
# 2                 165             <=    Bad Doctor Relationship
# 3                 147             <=             Less Knowledge
# 4                  93             <=               Bad Attitude
# 5                  81             <=     Low Anticipated Regret
# 6                  80              >         No Cues for Action
# 7                  55              >    No Trust on Vaccination
# 8                  30              >        Low risk perception
# 9                  26             <=       Good past Experience
# 10                 84             <=    No Trust on Vaccination
# 11                 67             <=     Low Anticipated Regret
# 12                 45             <=         No Cues for Action
# 13                 40             <=  Low trust on Info Channel
# 14                233              >    No Trust on Vaccination
# 15                201             <=              Less Barriers
# 16                180              >         No Cues for Action
# 17                137              >  Low trust on Info Channel
# 18                254             <=         No Cues for Action
# 19                218             <=    No Trust on Vaccination
# 20                 78              >               Bad Attitude
# 21                 88              >         No Cues for Action
# 22                 65              >    No Trust on Vaccination
# 23                 38              >        Low risk perception
# 24                 26              >    Bad Doctor Relationship
# 25                 96             <=         No Cues for Action
# 26                 57             <=    No Trust on Vaccination
# 27                 46             <=       Good past Experience
# 28                 29             <=    Bad Doctor Relationship
# 29                 22              >              Less Barriers
# ..                ...            ...                        ...
# 188                31             <=              Less Barriers
# 189                15             <=    Bad Doctor Relationship
# 190                11             <=     Low Anticipated Regret
# 191                 9             <=            Low Availablity
# 192                 6             <=        Low risk perception
# 193               259              >         No Cues for Action
# 194               194              >     Low Anticipated Regret
# 195                97             <=               Bad Attitude
# 196                82              >            Low Availablity
# 197               301             <=         No Cues for Action
# 198               235             <=    No Trust on Vaccination
# 199               189             <=     Low Anticipated Regret
# 200               153             <=            Low Availablity
# 201               129             <=             Less Knowledge
# 202               105             <=        Low risk perception
# 203               273              >         No Cues for Action
# 204               232              >    No Trust on Vaccination
# 205               183              >            Low Availablity
# 206               143              >     Low Anticipated Regret
# 207               125             <=              Less Barriers
# 208                72             <=               Bad Attitude
# 209                66              >              Less Barriers
# 210                34             <=        Low risk perception
# 211                31             <=     Low Anticipated Regret
# 212                21             <=            Low Availablity
# 213                17             <=             Less Knowledge
# 214                14             <=         No Cues for Action
# 215                31             <=              Less Barriers
# 216                28              >    No Trust on Vaccination
# 217                22              >            Low Availablity
#
#                         pos_map                    Col_Name
# 0         Given Cues for Action          No Cues for Action
# 1     Have Trust on Vaccination     No Trust on Vaccination
# 2     Good  Doctor Relationship     Bad Doctor Relationship
# 3                Good Knowledge              Less Knowledge
# 4                 Good Attitude                Bad Attitude
# 5       High Anticipated Regret      Low Anticipated Regret
# 6         Given Cues for Action       Given Cues for Action
# 7     Have Trust on Vaccination   Have Trust on Vaccination
# 8          High risk perception        High risk perception
# 9           Bad past Experience        Good past Experience
# 10    Have Trust on Vaccination     No Trust on Vaccination
# 11      High Anticipated Regret      Low Anticipated Regret
# 12        Given Cues for Action          No Cues for Action
# 13   High trust on Info Channel   Low trust on Info Channel
# 14    Have Trust on Vaccination   Have Trust on Vaccination
# 15                More Barriers               Less Barriers
# 16        Given Cues for Action       Given Cues for Action
# 17   High trust on Info Channel  High trust on Info Channel
# 18        Given Cues for Action          No Cues for Action
# 19    Have Trust on Vaccination     No Trust on Vaccination
# 20                Good Attitude               Good Attitude
# 21        Given Cues for Action       Given Cues for Action
# 22    Have Trust on Vaccination   Have Trust on Vaccination
# 23         High risk perception        High risk perception
# 24    Good  Doctor Relationship   Good  Doctor Relationship
# 25        Given Cues for Action          No Cues for Action
# 26    Have Trust on Vaccination     No Trust on Vaccination
# 27          Bad past Experience        Good past Experience
# 28    Good  Doctor Relationship     Bad Doctor Relationship
# 29                More Barriers               More Barriers
# ..                          ...                         ...
# 188               More Barriers               Less Barriers
# 189   Good  Doctor Relationship     Bad Doctor Relationship
# 190     High Anticipated Regret      Low Anticipated Regret
# 191            High Availablity             Low Availablity
# 192        High risk perception         Low risk perception
# 193       Given Cues for Action       Given Cues for Action
# 194     High Anticipated Regret     High Anticipated Regret
# 195               Good Attitude                Bad Attitude
# 196            High Availablity            High Availablity
# 197       Given Cues for Action          No Cues for Action
# 198   Have Trust on Vaccination     No Trust on Vaccination
# 199     High Anticipated Regret      Low Anticipated Regret
# 200            High Availablity             Low Availablity
# 201              Good Knowledge              Less Knowledge
# 202        High risk perception         Low risk perception
# 203       Given Cues for Action       Given Cues for Action
# 204   Have Trust on Vaccination   Have Trust on Vaccination
# 205            High Availablity            High Availablity
# 206     High Anticipated Regret     High Anticipated Regret
# 207               More Barriers               Less Barriers
# 208               Good Attitude                Bad Attitude
# 209               More Barriers               More Barriers
# 210        High risk perception         Low risk perception
# 211     High Anticipated Regret      Low Anticipated Regret
# 212            High Availablity             Low Availablity
# 213              Good Knowledge              Less Knowledge
# 214       Given Cues for Action          No Cues for Action
# 215               More Barriers               Less Barriers
# 216   Have Trust on Vaccination   Have Trust on Vaccination
# 217            High Availablity            High Availablity
#
# [218 rows x 10 columns]

# %%
master_analysis_data.to_csv("..//output//master_analysis_data.csv",index=False)
